# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("Advertising.csv")
data.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
X = data.drop("sales", axis=1)
y = data["sales"]

# %%
X
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: sales, Length: 200, dtype: float64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.25, random_state=101)
model = LinearRegression()
model.fit(X_train, Y_train)
Y_test.head()
# Out:
# 37     14.7
# 109    19.8
# 31     11.9
# 89     16.7
# 66      9.5
# Name: sales, dtype: float64

# %%
some_val = pd.DataFrame.from_dict({"TV": [280, 45], "radio": [38, 45], "newspaper": [70, 45]})

model.predict(some_val)
# Out:
# array([22.79405755, 13.55436265])

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, root_mean_squared_error

mae = mean_absolute_error(Y_test, model.predict(X_test))
mse = mean_squared_error(Y_test, model.predict(X_test))
rmse = root_mean_squared_error(Y_test, model.predict(X_test))

print(f"Mean absolute error: {mae}")
print(f"Mean squared error: {mse}")
print(f"Root mean square error: {rmse}")
# Out:
# Mean absolute error: 1.1385860673647974
# Mean squared error: 2.1086081578175144
# Root mean square error: 1.4521047337632071

# %%
# Evaluation residuals error for linear regression

# %%
resi = Y_test - model.predict(X_test)
sns.scatterplot(x=Y_test, y=resi)
plt.axhline(y=0)
sns.displot(resi, bins=10, kde=True)
import scipy as sp

fig, ax = plt.subplots()
sp.stats.probplot(resi, plot=ax)
# Out:
# ((array([-2.20385432, -1.83293478, -1.61402323, -1.45296849, -1.32267759,
#          -1.21163342, -1.113805  , -1.02561527, -0.94475674, -0.86964726,
#          -0.79915021, -0.73241807, -0.66879925, -0.6077796 , -0.54894415,
#          -0.49195112, -0.43651377, -0.38238727, -0.32935914, -0.27724191,
#          -0.2258675 , -0.17508277, -0.12474591, -0.07472335, -0.02488719,
#           0.02488719,  0.07472335,  0.12474591,  0.17508277,  0.2258675 ,
#           0.27724191,  0.32935914,  0.38238727,  0.43651377,  0.49195112,
#           0.54894415,  0.6077796 ,  0.66879925,  0.73241807,  0.79915021,
#           0.86964726,  0.94475674,  1.02561527,  1.113805  ,  1.21163342,
#           1.32267759,  1.45296849,  1.61402323,  1.83293478,  2.20385432]),
#   array([-3.59297513e+00, -3.45083867e+00, -3.21714230e+00, -3.18247057e+00,
#          -2.10946471e+00, -1.52445110e+00, -1.43684688e+00, -1.39336555e+00,
#          -1.14236433e+00, -1.02638870e+00, -9.92318734e-01, -9.47231081e-01,
# ...

# %%
final_model_lr = LinearRegression()
final_model_lr.fit(X,y)
final_model_lr.coef_
# Out:
# array([ 0.04576465,  0.18853002, -0.00103749])

# %%
from joblib import dump,load
dump(final_model_lr,"model.joblib")
loaded_model = load("model.joblib")

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("Advertising.csv")

# %%
data
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
X = data.drop("sales",axis=1)

# %%
X
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y = data["sales"]

# %%
(X_train,x_test,Y_train,y_test)= train_test_split(X,y,test_size=0.3,random_state=100)

# %%
y_test
# Out:
# 126     6.6
# 104    20.7
# 99     17.2
# 92     19.4
# 111    21.8
# 167    12.2
# 116    12.2
# 96     11.7
# 52     22.6
# 69     22.3
# 164    11.9
# 124    19.7
# 182     8.7
# 154    15.6
# 125    10.6
# 196     9.7
# 194    17.3
# 177    11.7
# 163    18.0
# 31     11.9
# 11     17.4
# 73     11.0
# 15     22.4
# 41     17.1
# 97     15.5
# 128    24.7
# 133    19.6
# 82     11.3
# 139    20.7
# 123    15.2
# 83     13.6
# 65      9.3
# 151    11.6
# 162    14.9
# 170     8.4
# 77     14.2
# 32      9.6
# 173    11.7
# 174    11.5
# 85     15.2
# 168    17.1
# 112    14.1
# 171    14.5
# 181    12.2
# 7      13.2
# 46     10.6
# 75      8.7
# 28     18.9
# 29     10.5
# 195     7.6
# 40     16.6
# 153    19.0
# 115    12.6
# 64     18.0
# 59     18.4
# 1      10.4
# 192     5.9
# 136     9.5
# 152    16.6
# 161    13.3
# Name: sales, dtype: float64
